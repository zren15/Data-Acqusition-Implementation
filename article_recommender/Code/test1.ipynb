# %%
# Launch with
#
# gunicorn -D --threads 4 -b 0.0.0.0:5000 --access-logfile server.log --timeout 60 server:app glove.6B.300d.txt bbc

from flask import Flask, render_template
from doc2vec import *
import sys

app = Flask(__name__)

@app.route("/")
def a():
    """Show a list of article titles"""
    return render_template("articles.html",articles_links=articles_links)

# article = [filename,title,article_text_minus_title,wordvec]

@app.route("/article/<topic>/<filename>")
def b(topic,filename):
    """
    Show an article with relative path filename. Assumes the BBC structure of
    topic/filename.txt so our URLs follow that.
    """
    for i in range(len(articles)):
        if topic+'/'+filename in articles[i][0]:
            article = articles[i]
    title = article[1]
    return render_template('article1.html', title=title)
   
app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/Oct/2021 21:04:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Oct/2021 21:04:22] "GET /article/entertainment/289.txt HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Oct/2021 21:04:24] "GET /article/entertainment/262.txt HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Oct/2021 21:04:26] "GET /article/entertainment/276.txt HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Oct/2021 21:04:29] "GET /article/entertainment/074.txt HTTP/1.1" 200 -

# %%
# Launch with
#
# gunicorn -D --threads 4 -b 0.0.0.0:5000 --access-logfile server.log --timeout 60 server:app glove.6B.300d.txt bbc

from flask import Flask, render_template
from doc2vec import *
import sys

app = Flask(__name__)

@app.route("/")
def articles():
    """Show a list of article titles"""
    return render_template("articles.html",articles_links=articles_links)

# article = [filename,title,article_text_minus_title,wordvec]

@app.route("/article/<topic>/<filename>")
def article(topic,filename):
    """
    Show an article with relative path filename. Assumes the BBC structure of
    topic/filename.txt so our URLs follow that.
    """
    
    for i in range(len(articles)):
        if topic+'/'+filename in articles[i][0]:
            article = articles[i]
            break
    title = article[1]
    article_text = article[2].split("\n")
    recommend=recommended(article,articles,5)
    recommend_lst=[]
    for fa in recommend:
        path = fa[0].split("/")[-2:]
        path = '/'.join(path)
        recommend_lst.append([fa[1],f'/article/{path}'])
    return render_template('article.html', title=title, article_text = article_text,recommend_lst=recommend_lst)

# i = sys.argv.index('server:app')
# glove_filename = sys.argv[i+1]
# articles_dirname = sys.argv[i+2]


gloves = load_glove('glove.6B.300d.txt') # can txt file can be downloaded from https://www.kaggle.com/datasets/thanakomsn/glove6b300dtxt
articles = load_articles('bbc', gloves)
articles_links = [['/article/'+f[0].split('/',1)[1],f[1]] for f in articles]


app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/Oct/2021 21:14:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Oct/2021 21:14:22] "GET /article/entertainment/289.txt HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Oct/2021 21:14:27] "GET /article/entertainment/048.txt HTTP/1.1" 200 -
# 127.0.0.1 - - [02/Oct/2021 21:14:32] "GET /article/entertainment/289.txt HTTP/1.1" 200 -

# %%
from flask import Flask, render_template
from doc2vec import *
import sys

gloves = load_glove('glove.6B.300d.txt') # can txt file can be downloaded from https://www.kaggle.com/datasets/thanakomsn/glove6b300dtxt
articles = load_articles('bbc', gloves)
articles_links = [['/article/'+f[0].split('/',1)[1],f[1]] for f in articles]

# %%
recommend=recommended(articles[1],articles,5)

# %%
recommend
# Out:
# [['bbc/entertainment/236.txt',
#   "Franz Ferdinand's art school lesson",
# ...
